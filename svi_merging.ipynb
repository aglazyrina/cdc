# %%
# Import packages
import pandas as pd
import os

# Import data
svi2014 = pd.read_csv('original_dataset.csv')
svi2016 = pd.read_csv('SVI2016_US.csv')
svi2018 = pd.read_csv('SVI2018_US.csv')

# %%
def count_out_of_range(value_list):
    oor = 0
    ir = 0
    for value in value_list:
        if value < -1 or value > 1:
            oor+=1
        else:
            ir+=1
    print('Percent out of range: {}%'.format((oor*100)/(oor+ir)))
# Drop uncommon columns
# 2014 - 127 columns... AFFGEOID, TRACTIC, FID
# 2016 - 125 columns... FID
# 2018 - 124 columns
svi2014 = svi2014.drop(['AFFGEOID', 'TRACTCE', 'FID'], axis = 1)
svi2016 = svi2016.drop('FID', axis = 1)

# %%
# Merge datasets
svimain = svi2014.merge(svi2016, on = 'FIPS', suffixes = ['_2014', '_2016'])
svimain = svimain.merge(svi2018, on = 'FIPS')

# %%
svimain.head()
# Out:
#    ST_2014 STATE_2014 ST_ABBR_2014  STCNTY_2014 COUNTY_2014         FIPS  \
# 0       36   New York           NY        36065      Oneida  36065023400
# 1       36   New York           NY        36065      Oneida  36065023501
# 2       36   New York           NY        36065      Oneida  36065023502
# 3       36   New York           NY        36065      Oneida  36065023702
# 4       36   New York           NY        36065      Oneida  36065023901
#
#                                   LOCATION_2014  AREA_SQMI_2014  \
# 0     Census Tract 234, Oneida County, New York        2.431604
# 1  Census Tract 235.01, Oneida County, New York        1.174765
# 2  Census Tract 235.02, Oneida County, New York        8.891521
# 3  Census Tract 237.02, Oneida County, New York       34.616428
# 4  Census Tract 239.01, Oneida County, New York        2.327858
#
#    E_TOTPOP_2014  M_TOTPOP_2014  ...  F_CROWD  F_NOVEH  F_GROUPQ  F_THEME4  \
# 0           4432            445  ...        0        0         1         1
# 1           2406            137  ...        0        0         0         0
# 2           4498            298  ...        0        0         0         0
# 3           3799             39  ...        0        0         0         0
# 4           2298            103  ...        0        0         0         0
#
#    F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP
# 0        2         30         39         0.7         0.8     10969
# 1        1         37         38         1.6         1.7       794
# 2        0         15         23         0.3         0.5      2886
# 3        0        285        145         7.6         3.9      1492
# 4        0         74         62         3.4         2.8      2327
#
# [5 rows x 372 columns]

# %%
maincols = svimain.columns.values.tolist()
maincols.sort()
maincols
# Out:
# ['AREA_SQMI',
#  'AREA_SQMI_2014',
#  'AREA_SQMI_2016',
#  'COUNTY',
#  'COUNTY_2014',
#  'COUNTY_2016',
#  'EPL_AGE17',
#  'EPL_AGE17_2014',
#  'EPL_AGE17_2016',
#  'EPL_AGE65',
#  'EPL_AGE65_2014',
#  'EPL_AGE65_2016',
#  'EPL_CROWD',
#  'EPL_CROWD_2014',
#  'EPL_CROWD_2016',
#  'EPL_DISABL',
#  'EPL_DISABL_2014',
#  'EPL_DISABL_2016',
#  'EPL_GROUPQ',
#  'EPL_GROUPQ_2014',
#  'EPL_GROUPQ_2016',
#  'EPL_LIMENG',
#  'EPL_LIMENG_2014',
#  'EPL_LIMENG_2016',
#  'EPL_MINRTY',
#  'EPL_MINRTY_2014',
#  'EPL_MINRTY_2016',
#  'EPL_MOBILE',
#  'EPL_MOBILE_2014',
#  'EPL_MOBILE_2016',
#  'EPL_MUNIT',
#  'EPL_MUNIT_2014',
#  'EPL_MUNIT_2016',
#  'EPL_NOHSDP',
#  'EPL_NOHSDP_2014',
#  'EPL_NOHSDP_2016',
#  'EPL_NOVEH',
#  'EPL_NOVEH_2014',
#  'EPL_NOVEH_2016',
#  'EPL_PCI',
#  'EPL_PCI_2014',
#  'EPL_PCI_2016',
#  'EPL_POV',
#  'EPL_POV_2014',
#  'EPL_POV_2016',
#  'EPL_SNGPNT',
#  'EPL_SNGPNT_2014',
#  'EPL_SNGPNT_2016',
#  'EPL_UNEMP',
#  'EPL_UNEMP_2014',
#  'EPL_UNEMP_2016',
#  'EP_AGE17',
#  'EP_AGE17_2014',
#  'EP_AGE17_2016',
#  'EP_AGE65',
#  'EP_AGE65_2014',
#  'EP_AGE65_2016',
#  'EP_CROWD',
#  'EP_CROWD_2014',
#  'EP_CROWD_2016',
#  'EP_DISABL',
#  'EP_DISABL_2014',
#  'EP_DISABL_2016',
#  'EP_GROUPQ',
#  'EP_GROUPQ_2014',
#  'EP_GROUPQ_2016',
#  'EP_LIMENG',
#  'EP_LIMENG_2014',
#  'EP_LIMENG_2016',
#  'EP_MINRTY',
#  'EP_MINRTY_2014',
#  'EP_MINRTY_2016',
#  'EP_MOBILE',
#  'EP_MOBILE_2014',
#  'EP_MOBILE_2016',
#  'EP_MUNIT',
#  'EP_MUNIT_2014',
#  'EP_MUNIT_2016',
#  'EP_NOHSDP',
#  'EP_NOHSDP_2014',
#  'EP_NOHSDP_2016',
#  'EP_NOVEH',
#  'EP_NOVEH_2014',
#  'EP_NOVEH_2016',
#  'EP_PCI',
#  'EP_PCI_2014',
#  'EP_PCI_2016',
#  'EP_POV',
#  'EP_POV_2014',
#  'EP_POV_2016',
#  'EP_SNGPNT',
#  'EP_SNGPNT_2014',
#  'EP_SNGPNT_2016',
#  'EP_UNEMP',
#  'EP_UNEMP_2014',
#  'EP_UNEMP_2016',
#  'EP_UNINSUR',
#  'EP_UNINSUR_2014',
#  'EP_UNINSUR_2016',
#  'E_AGE17',
#  'E_AGE17_2014',
#  'E_AGE17_2016',
#  'E_AGE65',
#  'E_AGE65_2014',
#  'E_AGE65_2016',
#  'E_CROWD',
#  'E_CROWD_2014',
#  'E_CROWD_2016',
#  'E_DAYPOP',
#  'E_DAYPOP_2014',
#  'E_DAYPOP_2016',
#  'E_DISABL',
#  'E_DISABL_2014',
#  'E_DISABL_2016',
#  'E_GROUPQ',
#  'E_GROUPQ_2014',
#  'E_GROUPQ_2016',
#  'E_HH',
#  'E_HH_2014',
#  'E_HH_2016',
#  'E_HU',
#  'E_HU_2014',
#  'E_HU_2016',
#  'E_LIMENG',
#  'E_LIMENG_2014',
#  'E_LIMENG_2016',
#  'E_MINRTY',
#  'E_MINRTY_2014',
#  'E_MINRTY_2016',
#  'E_MOBILE',
#  'E_MOBILE_2014',
#  'E_MOBILE_2016',
#  'E_MUNIT',
#  'E_MUNIT_2014',
#  'E_MUNIT_2016',
#  'E_NOHSDP',
#  'E_NOHSDP_2014',
#  'E_NOHSDP_2016',
#  'E_NOVEH',
#  'E_NOVEH_2014',
#  'E_NOVEH_2016',
#  'E_PCI',
#  'E_PCI_2014',
#  'E_PCI_2016',
#  'E_POV',
#  'E_POV_2014',
#  'E_POV_2016',
#  'E_SNGPNT',
#  'E_SNGPNT_2014',
#  'E_SNGPNT_2016',
#  'E_TOTPOP',
#  'E_TOTPOP_2014',
#  'E_TOTPOP_2016',
#  'E_UNEMP',
#  'E_UNEMP_2014',
#  'E_UNEMP_2016',
#  'E_UNINSUR',
#  'E_UNINSUR_2014',
#  'E_UNINSUR_2016',
#  'FIPS',
#  'F_AGE17',
#  'F_AGE17_2014',
#  'F_AGE17_2016',
#  'F_AGE65',
#  'F_AGE65_2014',
#  'F_AGE65_2016',
#  'F_CROWD',
#  'F_CROWD_2014',
#  'F_CROWD_2016',
#  'F_DISABL',
#  'F_DISABL_2014',
#  'F_DISABL_2016',
#  'F_GROUPQ',
#  'F_GROUPQ_2014',
#  'F_GROUPQ_2016',
#  'F_LIMENG',
#  'F_LIMENG_2014',
#  'F_LIMENG_2016',
#  'F_MINRTY',
#  'F_MINRTY_2014',
#  'F_MINRTY_2016',
#  'F_MOBILE',
#  'F_MOBILE_2014',
#  'F_MOBILE_2016',
#  'F_MUNIT',
#  'F_MUNIT_2014',
#  'F_MUNIT_2016',
#  'F_NOHSDP',
#  'F_NOHSDP_2014',
#  'F_NOHSDP_2016',
#  'F_NOVEH',
#  'F_NOVEH_2014',
#  'F_NOVEH_2016',
#  'F_PCI',
#  'F_PCI_2014',
#  'F_PCI_2016',
#  'F_POV',
#  'F_POV_2014',
#  'F_POV_2016',
#  'F_SNGPNT',
#  'F_SNGPNT_2014',
#  'F_SNGPNT_2016',
#  'F_THEME1',
#  'F_THEME1_2014',
#  'F_THEME1_2016',
#  'F_THEME2',
#  'F_THEME2_2014',
#  'F_THEME2_2016',
#  'F_THEME3',
#  'F_THEME3_2014',
#  'F_THEME3_2016',
#  'F_THEME4',
#  'F_THEME4_2014',
#  'F_THEME4_2016',
#  'F_TOTAL',
#  'F_TOTAL_2014',
#  'F_TOTAL_2016',
#  'F_UNEMP',
#  'F_UNEMP_2014',
#  'F_UNEMP_2016',
#  'LOCATION',
#  'LOCATION_2014',
#  'LOCATION_2016',
#  'MP_AGE17',
#  'MP_AGE17_2014',
#  'MP_AGE17_2016',
#  'MP_AGE65',
#  'MP_AGE65_2014',
#  'MP_AGE65_2016',
#  'MP_CROWD',
#  'MP_CROWD_2014',
#  'MP_CROWD_2016',
#  'MP_DISABL',
#  'MP_DISABL_2014',
#  'MP_DISABL_2016',
#  'MP_GROUPQ',
#  'MP_GROUPQ_2014',
#  'MP_GROUPQ_2016',
#  'MP_LIMENG',
#  'MP_LIMENG_2014',
#  'MP_LIMENG_2016',
#  'MP_MINRTY',
#  'MP_MINRTY_2014',
#  'MP_MINRTY_2016',
#  'MP_MOBILE',
#  'MP_MOBILE_2014',
#  'MP_MOBILE_2016',
#  'MP_MUNIT',
#  'MP_MUNIT_2014',
#  'MP_MUNIT_2016',
#  'MP_NOHSDP',
#  'MP_NOHSDP_2014',
#  'MP_NOHSDP_2016',
#  'MP_NOVEH',
#  'MP_NOVEH_2014',
#  'MP_NOVEH_2016',
#  'MP_PCI',
#  'MP_PCI_2014',
#  'MP_PCI_2016',
#  'MP_POV',
#  'MP_POV_2014',
#  'MP_POV_2016',
#  'MP_SNGPNT',
#  'MP_SNGPNT_2014',
#  'MP_SNGPNT_2016',
#  'MP_UNEMP',
#  'MP_UNEMP_2014',
#  'MP_UNEMP_2016',
#  'MP_UNINSUR',
#  'MP_UNINSUR_2014',
#  'MP_UNINSUR_2016',
#  'M_AGE17',
#  'M_AGE17_2014',
#  'M_AGE17_2016',
#  'M_AGE65',
#  'M_AGE65_2014',
#  'M_AGE65_2016',
#  'M_CROWD',
#  'M_CROWD_2014',
#  'M_CROWD_2016',
#  'M_DISABL',
#  'M_DISABL_2014',
#  'M_DISABL_2016',
#  'M_GROUPQ',
#  'M_GROUPQ_2014',
#  'M_GROUPQ_2016',
#  'M_HH',
#  'M_HH_2014',
#  'M_HH_2016',
#  'M_HU',
#  'M_HU_2014',
#  'M_HU_2016',
#  'M_LIMENG',
#  'M_LIMENG_2014',
#  'M_LIMENG_2016',
#  'M_MINRTY',
#  'M_MINRTY_2014',
#  'M_MINRTY_2016',
#  'M_MOBILE',
#  'M_MOBILE_2014',
#  'M_MOBILE_2016',
#  'M_MUNIT',
#  'M_MUNIT_2014',
#  'M_MUNIT_2016',
#  'M_NOHSDP',
#  'M_NOHSDP_2014',
#  'M_NOHSDP_2016',
#  'M_NOVEH',
#  'M_NOVEH_2014',
#  'M_NOVEH_2016',
#  'M_PCI',
#  'M_PCI_2014',
#  'M_PCI_2016',
#  'M_POV',
#  'M_POV_2014',
#  'M_POV_2016',
#  'M_SNGPNT',
#  'M_SNGPNT_2014',
#  'M_SNGPNT_2016',
#  'M_TOTPOP',
#  'M_TOTPOP_2014',
#  'M_TOTPOP_2016',
#  'M_UNEMP',
#  'M_UNEMP_2014',
#  'M_UNEMP_2016',
#  'M_UNINSUR',
#  'M_UNINSUR_2014',
#  'M_UNINSUR_2016',
#  'RPL_THEME1',
#  'RPL_THEME1_2014',
#  'RPL_THEME1_2016',
#  'RPL_THEME2',
#  'RPL_THEME2_2014',
#  'RPL_THEME2_2016',
#  'RPL_THEME3',
#  'RPL_THEME3_2014',
#  'RPL_THEME3_2016',
#  'RPL_THEME4',
#  'RPL_THEME4_2014',
#  'RPL_THEME4_2016',
#  'RPL_THEMES',
#  'RPL_THEMES_2014',
#  'RPL_THEMES_2016',
#  'SHAPE_Area',
#  'SHAPE_Length',
#  'SPL_THEME1',
#  'SPL_THEME1_2014',
#  'SPL_THEME1_2016',
#  'SPL_THEME2',
#  'SPL_THEME2_2014',
#  'SPL_THEME2_2016',
#  'SPL_THEME3',
#  'SPL_THEME3_2014',
#  'SPL_THEME3_2016',
#  'SPL_THEME4',
#  'SPL_THEME4_2014',
#  'SPL_THEME4_2016',
#  'SPL_THEMES',
#  'SPL_THEMES_2014',
#  'SPL_THEMES_2016',
#  'ST',
#  'STATE',
#  'STATE_2014',
#  'STATE_2016',
#  'STCNTY',
#  'STCNTY_2014',
#  'STCNTY_2016',
#  'ST_2014',
#  'ST_2016',
#  'ST_ABBR',
#  'ST_ABBR_2014',
#  'ST_ABBR_2016']

# %%
# Create new columns showing difference between poverty estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_POV_2016_2014_DIF'] = svimain['E_POV_2016'] - svimain['E_POV_2014']
svimain['E_POV_2018_2016_DIF'] = svimain['E_POV'] - svimain['E_POV_2016']
svimain['E_POV_2018_2014_DIF'] = svimain['E_POV'] - svimain['E_POV_2014']

# Create new columns showing difference between unemployment estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_UNEMP_2016_2014_DIF'] = svimain['E_UNEMP_2016'] - svimain['E_UNEMP_2014']
svimain['E_UNEMP_2018_2016_DIF'] = svimain['E_UNEMP'] - svimain['E_UNEMP_2016']
svimain['E_UNEMP_2018_2014_DIF'] = svimain['E_UNEMP'] - svimain['E_UNEMP_2014']

# Create new columns showing difference between per capita income estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_PCI_2016_2014_DIF'] = svimain['E_PCI_2016'] - svimain['E_PCI_2014']
svimain['E_PCI_2018_2016_DIF'] = svimain['E_PCI'] - svimain['E_PCI_2016']
svimain['E_PCI_2018_2014_DIF'] = svimain['E_PCI'] - svimain['E_PCI_2014']

# Create new columns showing difference between no HS diploma estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_NOHSDP_2016_2014_DIF'] = svimain['E_NOHSDP_2016'] - svimain['E_NOHSDP_2014']
svimain['E_NOHSDP_2018_2016_DIF'] = svimain['E_NOHSDP'] - svimain['E_NOHSDP_2016']
svimain['E_NOHSDP_2018_2014_DIF'] = svimain['E_NOHSDP'] - svimain['E_NOHSDP_2014']

# Create new columns showing difference between overall socieconomic
# theme estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['RPL_THEME1_2016_2014_DIF'] = svimain['RPL_THEME1_2016'] - svimain['RPL_THEME1_2014']
svimain['RPL_THEME1_2018_2016_DIF'] = svimain['RPL_THEME1'] - svimain['RPL_THEME1_2016']
svimain['RPL_THEME1_2018_2014_DIF'] = svimain['RPL_THEME1'] - svimain['RPL_THEME1_2014']

# Create new columns showing difference between ages 65 and older estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_AGE65_2016_2014_DIF'] = svimain['E_AGE65_2016'] - svimain['E_AGE65_2014']
svimain['E_AGE65_2018_2016_DIF'] = svimain['E_AGE65'] - svimain['E_AGE65_2016']
svimain['E_AGE65_2018_2014_DIF'] = svimain['E_AGE65'] - svimain['E_AGE65_2014']

# Create new columns showing difference between ages 17 and younger estimates from 2014 - 2016 
# and 2016 - 2018 and 2014 - 2018
svimain['E_AGE17_2016_2014_DIF'] = svimain['E_AGE17_2016'] - svimain['E_AGE17_2014']
svimain['E_AGE17_2018_2016_DIF'] = svimain['E_AGE17'] - svimain['E_AGE17_2016']
svimain['E_AGE17_2018_2014_DIF'] = svimain['E_AGE17'] - svimain['E_AGE17_2014']

# Create new columns showing difference between disability estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_DISABL_2016_2014_DIF'] = svimain['E_DISABL_2016'] - svimain['E_DISABL_2014']
svimain['E_DISABL_2018_2016_DIF'] = svimain['E_DISABL'] - svimain['E_DISABL_2016']
svimain['E_DISABL_2018_2014_DIF'] = svimain['E_DISABL'] - svimain['E_DISABL_2014']

# Create new columns showing difference between single parent households
# estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_SNGPNT_2016_2014_DIF'] = svimain['E_SNGPNT_2016'] - svimain['E_SNGPNT_2014']
svimain['E_SNGPNT_2018_2016_DIF'] = svimain['E_SNGPNT'] - svimain['E_SNGPNT_2016']
svimain['E_SNGPNT_2018_2014_DIF'] = svimain['E_SNGPNT'] - svimain['E_SNGPNT_2014']

# Create new columns showing difference between overall household composition and disability
# theme estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['RPL_THEME2_2016_2014_DIF'] = svimain['RPL_THEME2_2016'] - svimain['RPL_THEME2_2014']
svimain['RPL_THEME2_2018_2016_DIF'] = svimain['RPL_THEME2'] - svimain['RPL_THEME2_2016']
svimain['RPL_THEME2_2018_2014_DIF'] = svimain['RPL_THEME2'] - svimain['RPL_THEME2_2014']

# Create new columns showing difference between minority estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_MINRTY_2016_2014_DIF'] = svimain['E_MINRTY_2016'] - svimain['E_MINRTY_2014']
svimain['E_MINRTY_2018_2016_DIF'] = svimain['E_MINRTY'] - svimain['E_MINRTY_2016']
svimain['E_MINRTY_2018_2014_DIF'] = svimain['E_MINRTY'] - svimain['E_MINRTY_2014']

# Create new columns showing difference between English "less than well" estimates 
# from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_LIMENG_2016_2014_DIF'] = svimain['E_LIMENG_2016'] - svimain['E_LIMENG_2014']
svimain['E_LIMENG_2018_2016_DIF'] = svimain['E_LIMENG'] - svimain['E_LIMENG_2016']
svimain['E_LIMENG_2018_2014_DIF'] = svimain['E_LIMENG'] - svimain['E_LIMENG_2014']

# Create new columns showing difference between overall minority status and language
# theme estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['RPL_THEME3_2016_2014_DIF'] = svimain['RPL_THEME3_2016'] - svimain['RPL_THEME3_2014']
svimain['RPL_THEME3_2018_2016_DIF'] = svimain['RPL_THEME3'] - svimain['RPL_THEME3_2016']
svimain['RPL_THEME3_2018_2014_DIF'] = svimain['RPL_THEME3'] - svimain['RPL_THEME3_2014']

# Create new columns showing difference between 10+ units estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_MUNIT_2016_2014_DIF'] = svimain['E_MUNIT_2016'] - svimain['E_MUNIT_2014']
svimain['E_MUNIT_2018_2016_DIF'] = svimain['E_MUNIT'] - svimain['E_MUNIT_2016']
svimain['E_MUNIT_2018_2014_DIF'] = svimain['E_MUNIT'] - svimain['E_MUNIT_2014']

# Create new columns showing difference between mobile home estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_MOBILE_2016_2014_DIF'] = svimain['E_MOBILE_2016'] - svimain['E_MOBILE_2014']
svimain['E_MOBILE_2018_2016_DIF'] = svimain['E_MOBILE'] - svimain['E_MOBILE_2016']
svimain['E_MOBILE_2018_2014_DIF'] = svimain['E_MOBILE'] - svimain['E_MOBILE_2014']

# Create new columns showing difference between more people than rooms estimates 
# from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_CROWD_2016_2014_DIF'] = svimain['E_CROWD_2016'] - svimain['E_CROWD_2014']
svimain['E_CROWD_2018_2016_DIF'] = svimain['E_CROWD'] - svimain['E_CROWD_2016']
svimain['E_CROWD_2018_2014_DIF'] = svimain['E_CROWD'] - svimain['E_CROWD_2014']

# Create new columns showing difference between household with no vehicle available estimates
# from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_NOVEH_2016_2014_DIF'] = svimain['E_NOVEH_2016'] - svimain['E_NOVEH_2014']
svimain['E_NOVEH_2018_2016_DIF'] = svimain['E_NOVEH'] - svimain['E_NOVEH_2016']
svimain['E_NOVEH_2018_2014_DIF'] = svimain['E_NOVEH'] - svimain['E_NOVEH_2014']

# Create new columns showing difference between institulionalized group quarters estimates
# from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['E_GROUPQ_2016_2014_DIF'] = svimain['E_GROUPQ_2016'] - svimain['E_GROUPQ_2014']
svimain['E_GROUPQ_2018_2016_DIF'] = svimain['E_GROUPQ'] - svimain['E_GROUPQ_2016']
svimain['E_GROUPQ_2018_2014_DIF'] = svimain['E_GROUPQ'] - svimain['E_GROUPQ_2014']

# Create new columns showing difference between overall housing and transportation
# theme estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['RPL_THEME4_2016_2014_DIF'] = svimain['RPL_THEME4_2016'] - svimain['RPL_THEME4_2014']
svimain['RPL_THEME4_2018_2016_DIF'] = svimain['RPL_THEME4'] - svimain['RPL_THEME4_2016']
svimain['RPL_THEME4_2018_2014_DIF'] = svimain['RPL_THEME4'] - svimain['RPL_THEME4_2014']

# Create new columns showing difference between overall tract summary ranking
# theme estimates from 2014 - 2016 and 2016 - 2018 and 2014 - 2018
svimain['RPL_THEMES_2016_2014_DIF'] = svimain['RPL_THEMES_2016'] - svimain['RPL_THEMES_2014']
svimain['RPL_THEMES_2018_2016_DIF'] = svimain['RPL_THEMES'] - svimain['RPL_THEMES_2016']
svimain['RPL_THEMES_2018_2014_DIF'] = svimain['RPL_THEMES'] - svimain['RPL_THEMES_2014']

# %%
count_out_of_range(svimain['RPL_THEMES_2016_2014_DIF'])
count_out_of_range(svimain['RPL_THEMES_2018_2016_DIF'])
count_out_of_range(svimain['RPL_THEMES_2018_2014_DIF'])
# Out:
# Percent out of range: 0.2883387568480455%
# Percent out of range: 0.06727904326454394%
# Percent out of range: 0.3309030495256141%

# %%
# Subset dataset
svimain = svimain[['ST', 'STATE', 'ST_ABBR', 'STCNTY', 'COUNTY', 'FIPS', 'LOCATION', 'AREA_SQMI', 'E_POV_2016_2014_DIF',
                  'E_POV_2018_2016_DIF', 'E_POV_2018_2014_DIF','E_UNEMP_2016_2014_DIF',
                  'E_UNEMP_2018_2016_DIF', 'E_UNEMP_2018_2014_DIF','E_PCI_2016_2014_DIF', 'E_PCI_2018_2016_DIF',
                  'E_PCI_2018_2014_DIF', 'E_NOHSDP_2016_2014_DIF', 'E_NOHSDP_2018_2016_DIF', 'E_NOHSDP_2018_2014_DIF',
                  'RPL_THEME1_2016_2014_DIF', 'RPL_THEME1_2018_2016_DIF', 'RPL_THEME1_2018_2014_DIF',
                  'E_AGE65_2016_2014_DIF', 'E_AGE65_2018_2016_DIF', 'E_AGE65_2018_2014_DIF', 'E_AGE17_2016_2014_DIF',
                  'E_AGE17_2018_2016_DIF', 'E_AGE17_2018_2014_DIF', 'E_DISABL_2016_2014_DIF', 'E_DISABL_2018_2016_DIF',
                  'E_DISABL_2018_2014_DIF', 'E_SNGPNT_2016_2014_DIF', 'E_SNGPNT_2018_2016_DIF', 'E_SNGPNT_2018_2014_DIF',
                  'RPL_THEME2_2016_2014_DIF', 'RPL_THEME2_2018_2016_DIF', 'RPL_THEME2_2018_2014_DIF',
                  'E_MINRTY_2016_2014_DIF', 'E_MINRTY_2018_2016_DIF', 'E_MINRTY_2018_2014_DIF', 'E_LIMENG_2016_2014_DIF',
                  'E_LIMENG_2018_2016_DIF', 'E_LIMENG_2018_2014_DIF', 'RPL_THEME3_2016_2014_DIF', 'RPL_THEME3_2018_2016_DIF',
                  'RPL_THEME3_2018_2014_DIF', 'E_MUNIT_2016_2014_DIF', 'E_MOBILE_2018_2016_DIF', 'E_MUNIT_2018_2014_DIF',
                  'E_MOBILE_2016_2014_DIF', 'E_MOBILE_2018_2016_DIF', 'E_MOBILE_2018_2014_DIF', 'E_CROWD_2016_2014_DIF',
                  'E_CROWD_2018_2016_DIF', 'E_CROWD_2018_2014_DIF', 'E_NOVEH_2016_2014_DIF', 'E_NOVEH_2018_2016_DIF',
                  'E_NOVEH_2018_2014_DIF', 'E_GROUPQ_2016_2014_DIF', 'E_GROUPQ_2018_2016_DIF', 'E_GROUPQ_2018_2014_DIF',
                  'RPL_THEME4_2016_2014_DIF', 'RPL_THEME4_2018_2016_DIF', 'RPL_THEME4_2018_2014_DIF',
                  'RPL_THEMES_2016_2014_DIF', 'RPL_THEMES_2018_2016_DIF', 'RPL_THEMES_2018_2014_DIF']]

# Export dataset
svimain.to_csv('svi_main.csv')
